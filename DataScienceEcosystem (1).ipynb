# %% [markdown]
# ## Data Science Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook data science tools and ecosystems are summarized.

# %% [markdown]
# ## Data science languages
# Some of the popular languages that data scientists use are:
# ***Python***,
# ***R***,
# ***SQL***,
# ***Julia***,
# ***Java***,
# ***JavaScript***.

# %% [markdown]
# **Some of the commonely used data scientists libraries include**:
# ***ggplot***,
# ***dplyr***,
# ***Tensorflow***,
# ***NumPy***,
# ***Caret***,
# ***PyTorch***.

# %% [markdown]
# ### Data science tools:
# |Tool Category|Tool Name|Primary use|
# |:---:|:---|:---|
# |Development|**Jupiter Notebook**|Interactive code execution, development and documentation.|
# |Development|**R Studio**|IDE for R.|
# |Version control|**Git**|Tracking changes in code and collaborating with a team.|
# |Data storage/processing|**SQL**|Managing and querying relational database.|
# |Data storage or processing|**Apache Spark**|Large scale data processing & analytics.|
# |Visualization|**Tableu**|Business intelligence and interactive data dashboards.|

# %% [markdown]
# ### Arithmetic expressions
# Below are few examples of arithmeic expressions in python:
# **Addition and subraction**
# **Multiplication and division**
# **Exponents**

# %%
#Multiplication: 5 multiplied by 8
result_multiply = 5 * 8
print("Multiplication Result:",
result_multiply) 

#Addition: 15 added to 25
result_add = 15 + 25
print("Additional Result:", result_add)
# Out:
# Multiplication Result: 40
# Additional Result: 40

# %%
#Input value: 200 minutes
minutes_input = 200

#Conversion factor: There are 6o minutes in 1 hour
hours_output = minutes_input / 60

#Display the result using an f-string for clear output
print(f"{minutes_input} minutes is equal to {hours_output} hours.")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours.

# %% [markdown]
# ## Learning objectives ##
# By the end of this notebook you will be able to:
#
# ***identify data science languages and libraries***,
# ***Identify tools for jupiter version control: Git, and Apache Spark***,
# ***Demonstrate basic operations*** , and
# ***Practice markdown for structured documentation, headings, lists and tables***

# %% [markdown]
# ## Author
#
# This notebook was authored by:
# Hlophe Lomathemba Sakhile
